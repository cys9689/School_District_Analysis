# %%
import pandas as pd
import os
portland_crime_data="Gitlab/M4_Pandas_2_Activities_B3-Par_PortlandCrime_Unsolved_Resources_crime_incident_data2017.csv"

# %%
portland_crime_data=os.path.join("Gitlab","M4_Pandas_2_Activities_B3-Par_PortlandCrime_Unsolved_Resources_crime_incident_data2017.csv")

# %%
portland_crime_df=pd.read_csv(portland_crime_data)
portland_crime_df.head()
# Out:
#                     Address  Case Number Crime Against     Neighborhood  \
# 0                       NaN  17-X4762181        Person              NaN
# 1                       NaN  17-X4757824      Property       Centennial
# 2  200 BLOCK OF SE 78TH AVE    17-900367      Property       Montavilla
# 3                       NaN  17-X4748982      Property  Southwest Hills
# 4                       NaN  17-X4748982      Property  Southwest Hills
#
#    Number of Records Occur Date Occur Month Year  Occur Time  \
# 0                  1     1/1/96           1/1/96         800
# 1                  1    1/20/00           1/1/00        1615
# 2                  1    12/1/03          12/1/03         800
# 3                  1     1/1/10           1/1/10           0
# 4                  1     1/1/10           1/1/10           0
#
#    Offense Category  Offense Count                             Offense Type  \
# 0      Sex Offenses              1                                     Rape
# ...

# %%
portland_crime_df.isnull().head()
# Out:
#    Address  Case Number  Crime Against  Neighborhood  Number of Records  \
# 0     True        False          False          True              False
# 1     True        False          False         False              False
# 2    False        False          False         False              False
# 3     True        False          False         False              False
# 4     True        False          False         False              False
#
#    Occur Date  Occur Month Year  Occur Time  Offense Category  Offense Count  \
# 0       False             False       False             False          False
# 1       False             False       False             False          False
# 2       False             False       False             False          False
# 3       False             False       False             False          False
# 4       False             False       False             False          False
#
# ...

# %%
portland_crime_df.isnull().sum()
# Out:
# Address              3667
# Case Number             0
# Crime Against           0
# Neighborhood         1320
# Number of Records       0
# Occur Date              0
# Occur Month Year        0
# Occur Time              0
# Offense Category        0
# Offense Count           0
# Offense Type            0
# Open Data Lat        4320
# Open Data Lon        4320
# Open Data X          4320
# Open Data Y          4320
# Report Date             0
# Report Month Year       0
# dtype: int64

# %%
portland_crime_df.dropna()
# Out:
#                             Address Case Number Crime Against   Neighborhood  \
# 2          200 BLOCK OF SE 78TH AVE   17-900367      Property     Montavilla
# 5      5400 BLOCK OF NE MALLORY AVE   17-900129      Property           King
# 6         5000 BLOCK OF NE 19TH AVE   17-901079      Property         Vernon
# 7         5000 BLOCK OF NE 19TH AVE   17-901079      Property         Vernon
# 8         12000 BLOCK OF SE PINE ST   17-900253      Property      Hazelwood
# ...                             ...         ...           ...            ...
# 41026  10200 BLOCK OF NE SANDY BLVD   17-286419       Society       Parkrose
# 41027   8800 BLOCK OF NE SANDY BLVD   17-285386       Society         Sumner
# 41028     9700 BLOCK OF SE STARK ST   17-286082       Society      Hazelwood
# 41029     9700 BLOCK OF SE STARK ST   17-286413       Society      Hazelwood
# 41031  8000 BLOCK OF SE POWELL BLVD   17-286659       Society  Foster-Powell
#
# ...

# %%
portland_crime_df.isnull().sum()
# Out:
# Address              3667
# Case Number             0
# Crime Against           0
# Neighborhood         1320
# Number of Records       0
# Occur Date              0
# Occur Month Year        0
# Occur Time              0
# Offense Category        0
# Offense Count           0
# Offense Type            0
# Open Data Lat        4320
# Open Data Lon        4320
# Open Data X          4320
# Open Data Y          4320
# Report Date             0
# Report Month Year       0
# dtype: int64

# %%
portland_cleandata_df=portland_crime_df.dropna()

# %%
portland_cleandata_df.isnull().sum()
# Out:
# Address              0
# Case Number          0
# Crime Against        0
# Neighborhood         0
# Number of Records    0
# Occur Date           0
# Occur Month Year     0
# Occur Time           0
# Offense Category     0
# Offense Count        0
# Offense Type         0
# Open Data Lat        0
# Open Data Lon        0
# Open Data X          0
# Open Data Y          0
# Report Date          0
# Report Month Year    0
# dtype: int64

# %%
offense_type=portland_cleandata_df["Offense Type"].to_list()

# %%
print(offense_type)
# Out:
# ['False Pretenses/Swindle/Confidence Game', 'Identity Theft', 'False Pretenses/Swindle/Confidence Game', 'Identity Theft', 'Credit Card/ATM Fraud', 'Identity Theft', 'Identity Theft', 'Identity Theft', 'Embezzlement', 'Identity Theft', 'Shoplifting', 'All Other Larceny', 'All Other Larceny', 'Identity Theft', 'Identity Theft', 'Theft From Motor Vehicle', 'Theft From Motor Vehicle', 'All Other Larceny', 'Credit Card/ATM Fraud', 'Identity Theft', 'False Pretenses/Swindle/Confidence Game', 'Identity Theft', 'Identity Theft', 'Theft From Motor Vehicle', 'Theft From Motor Vehicle', 'Motor Vehicle Theft', 'Burglary', 'Theft From Motor Vehicle', 'Theft of Motor Vehicle Parts or Accessories', 'Motor Vehicle Theft', 'Counterfeiting/Forgery', 'Identity Theft', 'All Other Larceny', 'Burglary', 'False Pretenses/Swindle/Confidence Game', 'Theft of Motor Vehicle Parts or Accessories', 'Motor Vehicle Theft', 'False Pretenses/Swindle/Confidence Game', 'Theft of Motor Vehicle Parts or Accessories', '
# ...

# %%
for o_type in offense_type:
    print(o_type.split(),len(o_type.split()))
# Out:
# ['False', 'Pretenses/Swindle/Confidence', 'Game'] 3
# ['Identity', 'Theft'] 2
# ['False', 'Pretenses/Swindle/Confidence', 'Game'] 3
# ['Identity', 'Theft'] 2
# ['Credit', 'Card/ATM', 'Fraud'] 3
# ['Identity', 'Theft'] 2
# ['Identity', 'Theft'] 2
# ['Identity', 'Theft'] 2
# ['Embezzlement'] 1
# ['Identity', 'Theft'] 2
# ['Shoplifting'] 1
# ['All', 'Other', 'Larceny'] 3
# ['All', 'Other', 'Larceny'] 3
# ['Identity', 'Theft'] 2
# ['Identity', 'Theft'] 2
# ['Theft', 'From', 'Motor', 'Vehicle'] 4
# ['Theft', 'From', 'Motor', 'Vehicle'] 4
# ['All', 'Other', 'Larceny'] 3
# ['Credit', 'Card/ATM', 'Fraud'] 3
# ['Identity', 'Theft'] 2
# ['False', 'Pretenses/Swindle/Confidence', 'Game'] 3
# ['Identity', 'Theft'] 2
# ['Identity', 'Theft'] 2
# ['Theft', 'From', 'Motor', 'Vehicle'] 4
# ['Theft', 'From', 'Motor', 'Vehicle'] 4
# ['Motor', 'Vehicle', 'Theft'] 3
# ['Burglary'] 1
# ['Theft', 'From', 'Motor', 'Vehicle'] 4
# ['Theft', 'of', 'Motor', 'Vehicle', 'Parts', 'or', 'Accessories'] 7
# ...
